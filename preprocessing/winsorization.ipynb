# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961240
# std         0.615898
# min         4.890000
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         9.120000
# Name: cgpa, dtype: float64

# %%
sns.displot(df['cgpa'])

# %%
sns.boxplot(df['cgpa'])
# Out:
# <Axes: ylabel='cgpa'>

# %%
upperlimit=df['cgpa'].quantile(0.99)
upperlimit
# Out:
# np.float64(8.4201)

# %%
lowerlimit=df['cgpa'].quantile(0.01)
lowerlimit
# Out:
# np.float64(5.5596)

# %%
new_df=df[(df['cgpa']<=8.4 ) & (df['cgpa']>=5.559)]

# %%
new_df['cgpa'].describe()
# Out:
# count    979.000000
# mean       6.960255
# std        0.571720
# min        5.560000
# 25%        6.555000
# 50%        6.960000
# 75%        7.360000
# max        8.390000
# Name: cgpa, dtype: float64

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961240
# std         0.615898
# min         4.890000
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         9.120000
# Name: cgpa, dtype: float64

# %%
sns.displot(new_df['cgpa'])

# %%
sns.boxplot(new_df['cgpa'])
# Out:
# <Axes: ylabel='cgpa'>

# %%
df['cgpa']=np.where(df['cgpa']>=upperlimit,
         upperlimit,
        np.where(df['cgpa']<=lowerlimit,
        lowerlimit,
        df['cgpa']
         ))

# %%
df['cgpa'].shape
# Out:
# (1000,)
