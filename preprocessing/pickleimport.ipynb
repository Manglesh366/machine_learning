# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %%
test_input=np.array([1,'male',31.0,1,0,11,'C'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# c:\Users\INTEL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\INTEL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
