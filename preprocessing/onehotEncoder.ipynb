# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
df_1=pd.read_excel('employee.xlsx')
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data=df_1[['BusinessTravel','EducationField','Attrition']]
df=pd.DataFrame(data)
df.head(5)
# Out:
#       BusinessTravel EducationField Attrition
# 0      Travel_Rarely  Life Sciences       Yes
# 1  Travel_Frequently  Life Sciences        No
# 2      Travel_Rarely          Other       Yes
# 3  Travel_Frequently  Life Sciences        No
# 4      Travel_Rarely        Medical        No

# %%
pd.get_dummies(df,columns=['BusinessTravel'],drop_first=True)
# Out:
#      EducationField Attrition  BusinessTravel_Travel_Frequently  \
# 0     Life Sciences       Yes                             False
# 1     Life Sciences        No                              True
# 2             Other       Yes                             False
# 3     Life Sciences        No                              True
# 4           Medical        No                             False
# ...             ...       ...                               ...
# 1465        Medical        No                              True
# 1466        Medical        No                             False
# 1467  Life Sciences        No                             False
# 1468        Medical        No                              True
# 1469        Medical        No                             False
#
#       BusinessTravel_Travel_Rarely
# 0                             True
# 1                            False
# 2                             True
# 3                            False
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop('Attrition',axis=1),df['Attrition'],test_size=0.3,random_state=42)
# Out:
# (1029, 2)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop='first',sparse_output=True,dtype=np.int32)

X_train_trf=ohe.fit_transform(X_train[['EducationField','BusinessTravel']])

# %%
X_test_trf=ohe.transform(X_test[['EducationField','BusinessTravel']])

# %%
X_train_trf
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int32'
# 	with 1939 stored elements and shape (1029, 7)>

# %%
np.hstack(X_train)
# Out:
# array(['BusinessTravel', 'EducationField'], dtype='<U14')
