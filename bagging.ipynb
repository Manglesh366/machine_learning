# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df=df.drop(columns=['sepal_length','petal_width'])

# %%
df=df.sample(100)
df_train=df.iloc[:60,:]
df_val=df.iloc[60:80,:]
df_test=df.iloc[80:,:]

# %%
X_test=df_val.iloc[:,0:2]
y_test=df_val.iloc[:,-1]

# %%
df_bag=df_train.sample(8,replace=True)

X=df_bag.iloc[:,0:2]
y=df_bag.iloc[:,-1]

# %%
def evaluate(clf,X,y):
    clf.fit(X,y)
    plot_tree(clf)
    plt.show()
    plot_decision_regions(X.values,y.values,clf=clf,legend=2)
    y_pred=clf.predict(X_test)
    print(accuracy_score(y_test,y_pred))

# %%
DT1=DecisionTreeClassifier()
evaluate(DT1,X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 DT1=DecisionTreeClassifier()
# ----> 2 evaluate(DT1,X,y)
#
# Cell In[50], line 5, in evaluate(clf, X, y)
#       3 plot_tree(clf)
#       4 plt.show()
# ----> 5 plot_decision_regions(X.values,y.values,clf=clf,legend=2)
#       6 y_pred=clf.predict(X_test)
#       7 print(accuracy_score(y_test,y_pred))
#
# File c:\Users\INTEL\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlxtend\plotting\decision_regions.py:161, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#      50 def plot_decision_regions(
#      51     X,
#      52     y,
#    (...)     72     n_jobs=None,
#      73 ):
#      74     """Plot decision regions of a classifier.
#      75
#      76     Please note that this functions assumes that class labels are
#    (...)    158
#     159     """
# --> 161     check_Xy(X, y, y_int=True)  # Validate X and y arrays
#     162     dim = X.shape[1]
#     164     if n_jobs is None:
#
# File c:\Users\INTEL\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlxtend\utils\checking.py:20, in check_Xy(X, y, y_int)
#      17     raise ValueError("y must be a NumPy array. Found %s" % type(y))
#      19 if "int" not in str(y.dtype):
# ---> 20     raise ValueError(
#      21         "y must be an integer array. Found %s. "
#      22         "Try passing the array as y.astype(np.int_)" % y.dtype
#      23     )
#      25 if not ("float" in str(X.dtype) or "int" in str(X.dtype)):
#      26     raise ValueError("X must be an integer or float array. Found %s." % X.dtype)
#
# ValueError: y must be an integer array. Found object. Try passing the array as y.astype(np.int_)

# %%
df_bag
# Out:
#      sepal_width  petal_length     species
# 65           3.1           4.4  versicolor
# 36           3.5           1.3      setosa
# 127          3.0           4.9   virginica
# 61           3.0           4.2  versicolor
# 149          3.0           5.1   virginica
# 65           3.1           4.4  versicolor
# 98           2.5           3.0  versicolor
# 75           3.0           4.4  versicolor
