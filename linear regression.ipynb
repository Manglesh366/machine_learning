# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('placement1.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('marks')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test.head()
# Out:
#      cgpa
# 95   6.63
# 15   7.25
# 30   7.36
# 158  5.95
# 128  7.93

# %%
y_test.head()
# Out:
# 95     2.79
# 15     3.23
# 30     3.26
# 158    3.04
# 128    3.34
# Name: package, dtype: float64

# %%
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# c:\Users\INTEL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2750: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.13635249])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('cgpa')
plt.ylabel('package')
plt.show()

# %%
m=lr.coef_
print(m)
# Out:
# [0.57425647]

# %%
b=lr.intercept_

# %%
print(b)
# Out:
# -1.0270069374542108

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
lr.predict(X_test)
# Out:
# array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#        3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#        1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#        3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#        2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#        2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#        3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#        3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298])

# %%
y_pred=lr.predict(X_test)

# %%
print("MAE ",mean_absolute_error(y_test,y_pred))
# Out:
# MAE  0.23150985393278373

# %%
print("MSE ",mean_squared_error(y_test,y_pred))
# Out:
# MAE  0.08417638361329656

# %%
print("RMSE ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE  0.2901316659954521

# %%
print("r2score ",r2_score(y_test,y_pred))
r2=r2_score(y_test,y_pred)
# Out:
# r2score  0.7730984312051673

# %%
X_test.shape
# Out:
# (40, 1)

# %%
1-((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7671273372895138
