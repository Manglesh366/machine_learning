# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
X,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([78.35063668])

# %%
lr.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red')
plt.show()

# %%
y_pred=((78.35*X)+0).reshape(4)
print(y_pred)
# Out:
# [-55.81580837  35.39949674  -3.48681619  59.05759577]

# %%
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,label='B=0',color='orange')
plt.legend()
plt.show()

# %%
m=78.35
b=0

loss_slope =-2* np.sum(y-m*X.ravel()-b)
print(loss_slope)

LR=0.1
step_size=loss_slope*LR
print(step_size)
# Out:
# -209.27763408209216
# -20.927763408209216

# %%
b=b-step_size
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1=((78.35*X.ravel()-b).reshape(4))

# %%
plt.scatter(X,y)
plt.plot(X,lr.predict(X),color='red')
plt.plot(X,y_pred1,color='blue',label='B={}'.format(b))
plt.plot(X,y_pred,color='green',label='b=0')
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-78.35*X.ravel()-b)
step_size=loss_slope*LR
b=b-step_size
y_pred2=(78.35*X.ravel()-b).reshape(4)
plt.scatter(X,y)
plt.plot(X,y_pred,color='green',label='B=0')
plt.plot(X,y_pred1,color='blue',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-78.35*X.ravel()-b)
step_size=loss_slope*LR
b=b-step_size
y_pred3=(78.35*X.ravel()-b).reshape(4)
plt.scatter(X,y)
plt.plot(X,y_pred,color='green',label='B=0')
plt.plot(X,y_pred3,color='blue',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-78.35*X.ravel()-b)
step_size=loss_slope*LR
b=b-step_size
y_pred4=(78.35*X.ravel()-b).reshape(4)
plt.scatter(X,y)
plt.plot(X,y_pred,color='green',label='B=0')
plt.plot(X,y_pred4,color='blue',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-78.35*X.ravel()-b)
step_size=loss_slope*LR
b=b-step_size
y_pred5=(78.35*X.ravel()-b).reshape(4)
plt.scatter(X,y)
plt.plot(X,y_pred,color='green',label='B=0')
plt.plot(X,y_pred5,color='blue',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope=-2*np.sum(y-78.35*X.ravel()-b)
step_size=loss_slope*LR
b=b-step_size
y_pred6=(78.35*X.ravel()-b).reshape(4)
plt.scatter(X,y)
plt.plot(X,y_pred,color='green',label='B=0')
plt.plot(X,y_pred6,color='blue',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
m=78.35
b=-100
LR=0.1
epochs=10

for i in range(epochs):
    loss_slope=-2*np.sum(y-78.35*X.ravel()-b)
    step_size=loss_slope*LR
    b=b-step_size
    y_pred1=m*X+b
    y_pred=((78.35*X)+26.15963284313262).reshape(4)
    plt.scatter(X,y)
    plt.plot(X,y_pred1,color='red',label='B={}'.format(b))
    plt.plot(X,y_pred,color='green',label='B=0')
    plt.legend()
    plt.show()

# %%
26.15963284313262
